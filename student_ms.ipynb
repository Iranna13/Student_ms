# %%
import os
import pymysql
import pandas as pd
import getpass

 

host = os.getenv('MYSQL_HOST')
port = os.getenv('MYSQL_PORT')
user = os.getenv('MYSQL_USER')
password = os.getenv('MYSQL_PASSWORD')
database = os.getenv('MYSQL_DATABASE')

 

con = pymysql.connect(host=host, port=int(3306), user="root", passwd="root", db="student5",charset="utf8mb4")
c = con.cursor()
q = 'use student5'
c.execute(q)
df = pd.read_sql_query("SELECT * FROM students_det1",con)


def add_student():
    stu_name = input("Enter stu Name: ")
    stu_id = int(input("Enter stu id: "))
    stu_age = int(input("stu age: ") )
    gender = input("gender: ")
    stu_branch = input("Enter the branch:")
    fees = input("enter whether student amount paid or not:")
    total_clg_fee = int(input("enter the total college fee:"))
    if fees=="paid" or fees=="not":
        total_fee = 50000
        paid_amount = int(input("Enter how much amount you paid: "))  
        if paid_amount <= total_fee:
            remaining_amount = total_fee - paid_amount 
            print("The remaining amount to be paid by the student is: ", remaining_amount) 
    if paid_amount == total_fee:
        print("The student has paid the full amount.") 
            
    else:
        print("amount not paid completly.")
        
    data = (stu_name,stu_age,gender,stu_id,stu_branch,fees,total_fee,paid_amount,remaining_amount)
    sql = 'insert into students_det1 values(%s,%s,%s,%s,%s,%s,%s,%s,%s)'
    c = con.cursor()
    c.execute(sql,data)
    con.commit()
    print(">------------------------------------------------<")
    print("Data Entered Successfully")
    t=input("if u wanna run again enter y :").lower()
    if t=="y":
        main()

    

def stu_update():
    stu_id =int(input("Enter the ID of the student you want to update: "))


    new_name = input("Enter the new name: ")
    new_age = int(input("Enter the new age: "))
    new_gender = input("Enter the gender: ")
    stu_branch = input("Enter the branch:")
    fees = input("enter whether student amount paid or not:")
    total_clg_fee = int(input("enter the total college fee:"))
    
    if fees=="paid" or fees=="not":
        total_fee = 50000
        paid_amount = int(input("Enter how much amount you paid: "))  
        if paid_amount <= total_fee:
            remaining_amount = total_fee - paid_amount 
            print("The remaining amount to be paid by the student is: ", remaining_amount) 
    if paid_amount == total_fee:
        print("The student has paid the full amount.") 
            
    else:
        print("amount not paid completly.")

    

    sql="UPDATE students_det1 SET name=%s, age=%s,gender=%s,stu_branch=%s,fees=%s,total_fee=%s,amount_paid=%s,remaining_amount=%s WHERE stu_id=%s" 
    data=(new_name, new_age,new_gender,stu_branch,fees,total_fee,paid_amount,remaining_amount,stu_id)
    c = con.cursor()
    c.execute(sql,data)
    con.commit()
    print("Student details updated successfully!")

    t=input("if u wanna run again enter y :").lower()
    if t=="y":
        main()
        

    
def d_stu():
    ac = input("Enter stu_id: ")
    a = "delete from students_det1 where stu_id = %s"
    data = (ac,)
    c = con.cursor()
    c.execute(a,data)
    con.commit()
    print("deleted successfully")
    
    t=input("if u wanna run again enter y :").lower()
    if t=="y":
        main()
    
    
def disp_stu():
    a = "select * from students_det1" 
    c = con.cursor()
    c.execute(a)
    myresult = c.fetchall()
    for i in myresult:
        print("student Name : ",i[0])
        print("age: ",i[1])
        print("Gender: ",i[2])
        print("stu_id:",i[3])
        print("stu_branch:",i[4])
        print("fees:",i[5])
        print("total_fee:",i[6])
        print("paid_amount:",i[7])
        print("remaining_amount:",i[8])
        print(">----------------------------------------------<")
    
    t=input("if u wanna run again enter y :").lower()
    if t=="y":
        main()   


    
def main():
    print("""

            1. ADD student

            2. update student

            3. DELETE student

            4. DISPLAY student
                                """)

    choice = input("Enter Task No: ")
    print(">-------------------------------------------------<")

    if (choice == '1'):
        add_student()
    elif (choice=='2'):
        stu_update()
    elif (choice=='3'):
        d_stu()
    elif (choice=='4'):
        disp_stu()
    else:
        print(" Wrong choice...........")
        t=input("if u wanna run again enter y :").lower()
        if t=="y":
            main()
            
def pswd():
    ps = getpass.getpass(prompt="Enter your password")
    if ps == "stu89":
        main()
    else:
        print("Wrong Password")
        pswd()
pswd()
# Out:
# C:\Users\irann\anaconda3\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# Enter your password········
#
#
#             1. ADD student
#
#             2. update student
#
#             3. DELETE student
#
#             4. DISPLAY student
#
# Enter Task No: 3
# >-------------------------------------------------<
# Enter stu_id: 12
# deleted successfully
# if u wanna run again enter y :y
#
#
#             1. ADD student
#
#             2. update student
#
#             3. DELETE student
#
#             4. DISPLAY student
#
# Enter Task No: 4
# >-------------------------------------------------<
# student Name :  Ram
# age:  19
# Gender:  Male
# stu_id: 1
# stu_branch: EC
# fees: paid
# total_fee: 50000
# paid_amount: 50000
# remaining_amount: 0
# ...
